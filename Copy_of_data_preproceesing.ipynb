# %% [markdown]
# <a href="https://colab.research.google.com/github/faialqahtani14-coder/Object-Oriented-Programming-Online-Beauty-Shop-/blob/main/Copy_of_data_preproceesing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/caitlin-leonard/Seizure-analysis.git
# Out:
# Cloning into 'Seizure-analysis'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 68 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (68/68), 4.88 MiB | 5.82 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# !ls
# Out:
# sample_data  Seizure-analysis

# %%
import sys
sys.path.append("/content/Seizure-analysis")

# %%
# !ls Seizure-analysis
# Out:
# README.md  seizure_analysis

# %%
# !ls PN00
# Out:
# data_description_total.txt.swp	PN00-2.edf  Seizures-list-PN00.txt
# PN00-1.edf			PN00-3.edf

# %%
import os

print(os.path.exists("/content/PN00/PN00-1.edf"))
print(os.path.exists("/content/PN00/PN00-2.edf"))
print(os.path.exists("/content/PN00/PN00-3.edf"))
# Out:
# True
# True
# True

# %%
import pandas as pd

df = pd.read_csv("seizures.csv")
df_pn00 = df[df["patient_id"] == "PN00"].reset_index(drop=True)
df_pn00
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-394105557.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("seizures.csv")
#       4 df_pn00 = df[df["patient_id"] == "PN00"].reset_index(drop=True)
#       5 df_pn00
#
# ...

# %%
import pandas as pd

csv_path = "/content/Seizure-analysis/seizure_analysis/seizure_times.csv"
df = pd.read_csv(csv_path)

df_pn00 = df[df["patient_id"] == "PN00"].reset_index(drop=True)
df_pn00
# Out:
#   patient_id        file_name reg_start seiz_start  seiz_end
# 0       PN00  PN00/PN00-1.edf  19:39:33   19:58:36  19:59:46
# 1       PN00  PN00/PN00-2.edf  02:18:17   02:38:37  02:39:31
# 2       PN00  PN00/PN00-3.edf  18:15:44   18:28:29  19:29:29
# 3       PN00  PN00/PN00-4.edf  20:51:43   21:08:29  21:09:43
# 4       PN00  PN00/PN00-5.edf  22:22:04   22:37:08  22:38:15

# %%
from datetime import datetime

def time_to_seconds(t):
    t = datetime.strptime(t, "%H:%M:%S")
    return t.hour*3600 + t.minute*60 + t.second

# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 84.0 MB/s eta 0:00:00
# ...

# %%
# !find /content/Seizure-analysis -maxdepth 4 -type d -iname "signal*"

# %%
import sys
sys.path.append("/content/Seizure-analysis")

# %%
# !python /content/Seizure-analysis/seizure_analysis/1_visualisation.py
# Out:
# Visualizing all channels for file: PN00/PN00-1.edf
# Extracting EDF parameters from PN00/PN00-1.edf...
# Setting channel info structure...
# /content/Seizure-analysis/seizure_analysis/1_visualisation.py:8: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False)
# /content/Seizure-analysis/seizure_analysis/1_visualisation.py:8: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False)
# /content/Seizure-analysis/seizure_analysis/1_visualisation.py:8: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_file, preload=False)
# Creating raw.info structure...
# Reading 0 ... 15360  =      0.000 ...    30.000 secs...
# Using matplotlib as 2D backend.
# Figure(800x800)
# ...

# %%
# !sed -n '1,120p' /content/Seizure-analysis/seizure_analysis/1_visualisation.py
# Out:
# import pandas as pd
# import mne
#
# def visualize_all_channels_raw(edf_file, segment_seconds=30, start_seconds=0):
#     """
#     Visualize all EEG channels for the first segment_seconds of raw data.
#     """
#     raw = mne.io.read_raw_edf(edf_file, preload=False)
#     max_end = raw.times[-1]
#     t_end = min(max_end, start_seconds + segment_seconds)
#     raw_segment = raw.copy().crop(tmin=start_seconds, tmax=t_end)
#     raw_segment.load_data()
#     n_channels = len(raw_segment.ch_names)
#     raw_segment.plot(
#         n_channels=n_channels,
#         scalings='auto',
#         title=f'Raw EEG: {edf_file} (All {n_channels} channels, {start_seconds}-{t_end}s)',
#         show=True,
#         block=True
#     )
#
# # Load your CSV of file names
# df = pd.read_csv("seizure_times.csv")
# for idx, row in df.iterrows():
#     edf_file = row['file_name']
#     try:
#         print(f"Visualizing all channels for file: {edf_file}")
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/Seizure-analysis/seizure_analysis/seizure_times.csv")
df_pn00 = df[df["patient_id"]=="PN00"].reset_index(drop=True)

df_pn00.to_csv("/content/Seizure-analysis/seizure_analysis/seizure_times_PN00.csv", index=False)

# %%
# %cd /content/Seizure-analysis/seizure_analysis
# Out:
# /content/Seizure-analysis/seizure_analysis

# %%
# !ls
# Out:
# 1_visualisation.py			 4_analysis-entropy_ttest-boxplot.py
# 2_pre-processing.py			 5-thresholds-entropy.py
# 3_feature-extraction-bandpowervalues.py  6-detection.py
# 3_feature-extraction-entropy_values.py	 PN00
# 4_analysis-bandpower_bargraph.py	 preictal_flagged_segments.csv
# 4_analysis-bandpower_boxplot.py		 seizure_times.csv
# 4_analysis-entropy_bargraph.py		 seizure_times_PN00.csv

# %%
# %cd /content/Seizure-analysis/seizure_analysis
# !python 1_visualisation.py
# Out:
# /content/Seizure-analysis/seizure_analysis
# /content/Seizure-analysis/seizure_analysis/1_visualisation.py:12: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# /content/Seizure-analysis/seizure_analysis/1_visualisation.py:12: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# /content/Seizure-analysis/seizure_analysis/1_visualisation.py:12: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# Reading 0 ... 15360  =      0.000 ...    30.000 secs...
# Using matplotlib as 2D backend.
# Saved: /content/visualizations/PN00-1.png
# ...

# %%
# %cd /content/Seizure-analysis/seizure_analysis
# !python 2_pre-processing.py
# Out:
# /content/Seizure-analysis/seizure_analysis
# /content/Seizure-analysis/seizure_analysis/2_pre-processing.py:47: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# /content/Seizure-analysis/seizure_analysis/2_pre-processing.py:47: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# /content/Seizure-analysis/seizure_analysis/2_pre-processing.py:47: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# Reading 0 ... 15360  =      0.000 ...    30.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# ...

# %%
# %cd /content/Seizure-analysis/seizure_analysis
# !python 3_feature-extraction-bandpowervalues.py
# Out:
# /content/Seizure-analysis/seizure_analysis
# /content/Seizure-analysis/seizure_analysis/3_feature-extraction-bandpowervalues.py:88: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# /content/Seizure-analysis/seizure_analysis/3_feature-extraction-bandpowervalues.py:88: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# /content/Seizure-analysis/seizure_analysis/3_feature-extraction-bandpowervalues.py:88: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_file, preload=False, verbose=False)
# Reading 0 ... 15360  =      0.000 ...    30.000 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# ...
